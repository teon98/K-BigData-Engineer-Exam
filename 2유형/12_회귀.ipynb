# %% [markdown]
# ①탐색적 데이터 분석 <br>
# ②데이터 전처리 <br>
# ③데이터 셋 분할 <br>
# ④학습 <br>
# ⑤평가 <br>
# ⑥예측 및 결과 저장 <br>

# %% [markdown]
# ## 회귀 모델

# %% [markdown]
# ### 1. 랜덤포레스트(RandomForest)
# - 여러 개의 의사결정트리를 랜덤하게 학습시켜 앙상블하는 모델
# - 과적합을 방지하고 안정적인 예측력과 일반화 성능 확보에 유리
#
# ```python
# from sklearn.ensemble import RandomForestRegressor
# model = RandomForestRegressor()
# model.fit(X_train, y_train)
# ```

# %% [markdown]
# ### 2. XGBoost (근데 안씀)
# - 여러 개의 약한 결정트리 모델을 순차적으로 학습시켜 성능을 개선하는 부스팅 모델
# - 성능이 뛰어나고 과적합 제어도 가능
# - 과적합 우려가 있어 하이퍼파라미터 튜닝 필요
#
# ```python
# from xgboost import XGBRegressor
# model = XGBRegressor()
# model.fit(X_train, y)
# ```

# %% [markdown]
# ### 회귀 평가 지표
# | 지표 | 설명 | 해석 |
# | ---- | ---- | ---- |
# | MAE | 예측값과 실제값 차이의 절댓값 평균 | 값이 작을수록 좋음 |
# | MSE | 예측값과 실제값 차이의 제곱 평균 | 이상치에 민감, 값이 작을수록 좋음 |
# | R2 | 모델이 데이터를 얼마나 잘 설명하는지 | 1에 가까울수록 좋음 |
#
# ```python
# frmo sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
#
# #1. MAE
# mae = mean_absolute_error(y_true, y_pred)
#
# #2. MSE
# mae = mean_squared_error(y_true, y_pred)
#
# #3. r2_score
# r2 = r2_score(y_true, y_pred)
# ```
