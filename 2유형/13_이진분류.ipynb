# %% [markdown]
# ## 이진분류
#
# 1. 클래스 비율 동일 유지
# - `stratify=y` 는 훈련/검증 데이터에 클래스 비율을 동일하게 유지
# - 분류 문제에서 클래스 불균형이 있을 경우, 평가 신뢰도 확보에 필수
# - 예: 생존/사망, 정상/이상 여부 등 불균형 클래스에 효과적

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y, test_size=0.2, stratify=y)

# %% [markdown]
# ### 1. 랜덤포레스트(RandomForest)
# - 여러 개의 의사결정트리를 랜덤하게 학습시켜 앙상블하는 모델
# - 과적합을 방지하고 안정적인 예측력과 일반화 성능 확보에 유리

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train, y_train)

# %% [markdown]
# ### 2. XGBoost
# - 여러 개의 약한 결정트리 모델을 순차적으로 학습시켜 성능을 개선하는 부스팅 모델
# - 성능이 뛰어나고 과적합 제어도 가능
# - 과적합 우려가 있어 하이퍼파라미터 튜닝 필요

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(X_train, y_train)

# %% [markdown]
# ### 분류 평가 지표
# | 지표 | 설명 | 해석 |
# | --- | --- | --- |
# | ROC_AUC | ROC 커브의 아래 면적 <br> (양성/음성 분류의 종합 성능 지표) | 1에 가까울수록 좋음(0.5=랜덤) |
# | Accuracy | 전체 예측 중 정답 비율 | 높을 수록 좋음 |
# | Precision | 양성 예측 중 실제 양성 비율 | 높을 수록 좋음 |
# | Recall | 실제 양성 중 모델이 맞춘 비율 | 높을 수록 좋음 |
# | F1 Score | 정밀도와 재현율의 조화 평균 | 1에 가까울 수록 좋음 |

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, f1_score

# 예측값
y_pred = model.predict(X_val)
y_proba = model.predict_proba(X_val)[:,1]
# ROC_AUC 같은 경우 음성이 될 확률, 양성이 될 확률이 필요함. 
# 이를 위해 ROC_AUC만 predict_proba를 사용
# predict_proba는 (음성이 될 확률, 양성이 될 확률) 로 return 됨.
# 우리는 양성이 될 확률이 필요하여 [:,1]을 붙여줌

#지표 계산
roc_auc = roc_auc_score(y_true, y_proba)
acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred)
rec = recall_score(y_true, y_pred)
f1_score = f1_score(y_true, y_pred)
