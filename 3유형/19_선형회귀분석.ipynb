# %% [markdown]
# **회귀 분석**
# - 사례) 최종 성적(Y)을 출석률(X1)과 과제점수(X2)로 설명

# %%
import pandas as pd

df = pd.DataFrame({
    "출석률": [90, 85, 88, 75, 80, 95, 70, 65, 92, 78],
    "과제점수": [85, 80, 82, 70, 75, 90, 68, 60, 88, 72],
    "성적": [88, 82, 85, 74, 78, 92, 70, 65, 90, 76]
})

# %%
pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.6-cp310-cp310-macosx_11_0_arm64.whl (10.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 25.6 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: numpy<3,>=1.22.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from statsmodels) (2.2.6)
# Requirement already satisfied: packaging>=21.3 in /Users/taeyoung/Library/Python/3.10/lib/python/site-packages (from statsmodels) (25.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from statsmodels) (2.3.3)
# Collecting patsy>=0.5.6
#   Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 32.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from statsmodels) (1.15.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/taeyoung/Library/Python/3.10/lib/python/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/taeyoung/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-1.0.2 statsmodels-0.14.6
#
# [notice] A new release of pip available: 22.3.1 -> 26.1.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 1. 다중회귀분석 수행

# %%
import statsmodels.formula.api as smf

# 종속변수: 성적
# 독립변수: 출석률, 과제
model = smf.ols('성적 ~ 출석률 + 과제점수', data=df).fit() #oldirnay least Sqaures(최소제곱법)

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     성적   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                     1502.
# Date:                Sat, 20 Jun 2026   Prob (F-statistic):           6.06e-10
# Time:                        00:56:18   Log-Likelihood:                -5.2390
# No. Observations:                  10   AIC:                             16.48
# Df Residuals:                       7   BIC:                             17.39
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.0613      1.396      5.058      0.001       3.760      10.362
# 출석률            0.5512      0.145      3.793      0.007       0.208       0.895
# 과제점수           0.3617      0.149      2.427      0.046       0.009       0.714
# ==============================================================================
# Omnibus:                        0.739   Durbin-Watson:                   2.309
# Prob(Omnibus):                  0.691   Jarque-Bera (JB):                0.420
# Skew:                          -0.448   Prob(JB):                        0.811
# Kurtosis:                       2.547   Cond. No.                     1.02e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.02e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=10 observations were given.
#   return hypotest_fun_in(*args, **kwds)

# %% [markdown]
# # 풀이

# %%
print(dir(smf))
# Out:
# ['__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'conditional_logit', 'conditional_mnlogit', 'conditional_poisson', 'gee', 'glm', 'glmgam', 'gls', 'glsar', 'logit', 'mixedlm', 'mnlogit', 'negativebinomial', 'nominal_gee', 'ols', 'ordinal_gee', 'phreg', 'poisson', 'probit', 'quantreg', 'rlm', 'wls']

# %%
import statsmodels.formula.api as smf

# 종속변수: 성적
# 독립변수: 출석률, 과제점수
model = smf.ols('성적 ~ 출석률 + 과제점수', data=df).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     성적   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                     1502.
# Date:                Sat, 20 Jun 2026   Prob (F-statistic):           6.06e-10
# Time:                        00:57:31   Log-Likelihood:                -5.2390
# No. Observations:                  10   AIC:                             16.48
# Df Residuals:                       7   BIC:                             17.39
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.0613      1.396      5.058      0.001       3.760      10.362
# 출석률            0.5512      0.145      3.793      0.007       0.208       0.895
# 과제점수           0.3617      0.149      2.427      0.046       0.009       0.714
# ==============================================================================
# Omnibus:                        0.739   Durbin-Watson:                   2.309
# Prob(Omnibus):                  0.691   Jarque-Bera (JB):                0.420
# Skew:                          -0.448   Prob(JB):                        0.811
# Kurtosis:                       2.547   Cond. No.                     1.02e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.02e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=10 observations were given.
#   return hypotest_fun_in(*args, **kwds)

# %% [markdown]
# 2. 결과해석
#
# (1) 결정계수(R-squared, Adj. R-squared)
# - R-squared  = 0.998
#   → 전체 성적 변동의 99.8%를 출석률과 과제점수 두 변수로 설명 가능
# - Adj. R-squared = 0.997
#   → 설명변수 개수를 보정한 값으로도 99.7% 설명 가능
#
# (2) 회귀계수 (coef)
# - Intercept = 7.0613
# - 출석률 = 0.5512 (p=0.007)
#   → 출석률이 1% 증가할 때 성적은 약 0.55점 증가
#   → p < 0.05 이므로 통계적으로 유의미한 변수
# - 과제점수 = 0.3617 (p=0.046)
#   → 과제점수가 1점 증가할 때 성적은 약 0.36점 증가
#   → p < 0.05 이므로 통계적으로 유의미한 변수
#
# (3) 결론
# - 회귀식 : 성적 = 7.061 + 0.551 x 출석률 + 0.362 x 과제점수

# %% [markdown]
# 3. 상관계수 구하기

# %%
df[["출석률", "과제점수"]].corr()
# Out:
#            출석률      과제점수
# 출석률   1.000000  0.993559
# 과제점수  0.993559  1.000000

# %%
print('스피어만 상관 계수 : \n', df[["출석률", "과제점수"]].corr(method='spearman'))
print('켄달 상관 계수 : \n', df[["출석률", "과제점수"]].corr(method='kendall'))
# Out:
# 스피어만 상관 계수 :
#        출석률  과제점수
# 출석률   1.0   1.0
# 과제점수  1.0   1.0
# 켄달 상관 계수 :
#        출석률  과제점수
# 출석률   1.0   1.0
# 과제점수  1.0   1.0

# %% [markdown]
# 4. 출석률 82점, 과제점수 80점에 대해, 구축한 회귀 모델에서의 예상 성적 구하기

# %%
new_data = pd.DataFrame({"출석률": [82], "과제점수": [80]})
pred = model.predict(new_data)
print("예상성적", pred[0])
# Out:
# 예상성적 81.19539061176081

# %%
new_data = pd.DataFrame({"출석률": [82], "과제점수": [80]})
pred = model.predict(new_data)
print("예상 성적:", pred[0])
# Out:
# 예상 성적: 81.19539061176053
