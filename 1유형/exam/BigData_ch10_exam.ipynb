# %% [markdown]
# 제공된 데이터 biketrip.csv는 자전거 대여 서비스 이용 내역이다.
# 아래의 수행 순서에 따라 데이터를 처리하고, 구한 값을 소문항별로 [제출 형식]에 맞춰 입력하시오.
#
# [제공 데이터]
# 1. Start Time : 대여 시작 시각
# 2. Stop Time : 반납 시각
# 3. Station ID : 대여 시작 지점 ID
# 4. UserType : 이용자 유형
#
# [수행 순서]
# 1. Start Time과 Stop Time의 차이를 분 단위로 계산하여 새로운 컬럼 TripDuration을 생성한다.
# 2. 가장 오래 대여한 사용자가 대여한 Station ID를 구한다.
# 3. UserType별로 평균 TripDuration을 구한다.
# 4. 평균 TripDuration이 가장 높은 UserType의 평균 시간(분)을 구한다.
#
# [문제]
# 1. 수행 순서 2)에서 계산한 값을 입력하시오.
# ☞ [제출 형식] 정수(integer)로 작성
# 2. 수행 순서 3)에서 계산한 값을 입력하시오.
# ☞ [제출 형식] 버림하여 정수(integer)로 작성

# %%
import pandas as pd

df = pd.read_csv("../../sample_data/part1/biketrip.csv")

# 여기에 코드를 작성하시오.
# 1 
df['Start Time'] = pd.to_datetime(df['Start Time'])
df['Stop Time'] = pd.to_datetime(df['Stop Time'], format='%m/%d/%Y %H:%M')

df['TripDuration'] = (df['Stop Time'] - df['Start Time']).dt.total_seconds() / 60

# 2
print("정답2", df.loc[df['TripDuration'].idxmax(),'Station ID'].astype(int))

# 3
grouped = df.groupby('UserType')['TripDuration'].mean()
print("정답3", int(grouped.max()))
# Out:
# 정답2 3197
# 정답3 78

# %% [markdown]
# # 풀이

# %%
import pandas as pd

df = pd.read_csv("../../sample_data/part1/biketrip.csv")

# 1. Start Time과 Stop Time의 차이를 분 단위로 계산하여 새로운 컬럼 TripDuration을 생성한다.
df['Start Time'] = pd.to_datetime(df['Start Time'])
df['Stop Time'] = pd.to_datetime(df['Stop Time'], format='%m/%d/%Y %H:%M')

df['TripDuration'] = (df['Stop Time'] - df['Start Time']).dt.total_seconds() / 60

# 2. 가장 오래 대여한 사용자가 대여한 Station ID를 구한다.
longest_station_id = int(df.loc[df['TripDuration'].idxmax(), 'Station ID'])

print(df)
# 3. UserType별로 평균 TripDuration을 구한다.
avg_trip_by_user = df.groupby('UserType')['TripDuration'].mean()

# 4. 평균 TripDuration이 가장 높은 UserType의 평균 시간을 구한다.
max_avg_trip_duration = int(avg_trip_by_user.max())

# 결과
print("① 가장 오래 대여한 사용자가 대여한 Station ID :", longest_station_id)
print("② 평균 TripDuarion이 가장 높은 UserType의 평균 시간 :", max_avg_trip_duration)
# Out:
#                 Start Time           Stop Time  Station ID    UserType  \
# 0      2017-01-01 00:21:00 2017-01-01 00:24:00        3276  Subscriber
# 1      2017-01-01 00:24:00 2017-01-01 00:45:00        3183  Subscriber
# 2      2017-01-01 00:38:00 2017-01-01 00:44:00        3183  Subscriber
# 3      2017-01-01 00:38:00 2017-01-01 01:03:00        3194  Subscriber
# 4      2017-01-01 01:47:00 2017-01-01 01:58:00        3183  Subscriber
# ...                    ...                 ...         ...         ...
# 403170 2017-03-31 21:26:00 2017-03-31 21:30:00        3195  Subscriber
# 403171 2017-03-31 21:46:00 2017-03-31 21:50:00        3183  Subscriber
# 403172 2017-03-31 22:03:00 2017-03-31 22:07:00        3183  Subscriber
# 403173 2017-03-31 23:20:00 2017-03-31 23:30:00        3272  Subscriber
# 403174 2017-03-31 23:25:00 2017-03-31 23:36:00        3185  Subscriber
#
#         TripDuration
# 0                3.0
# 1               21.0
# 2                6.0
# 3               25.0
# 4               11.0
# ...              ...
# 403170           4.0
# 403171           4.0
# 403172           4.0
# 403173          10.0
# 403174          11.0
#
# [403175 rows x 5 columns]
# ① 가장 오래 대여한 사용자가 대여한 Station ID : 3197
# ② 평균 TripDuarion이 가장 높은 UserType의 평균 시간 : 78
