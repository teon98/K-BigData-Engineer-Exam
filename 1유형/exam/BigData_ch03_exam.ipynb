# %% [markdown]
# 제공된 데이터 housing.csv는 지역별 주택 가격과 인구 통계를 포함한 자료이다.
# 아래의 수행 순서에 따라 데이터를 처리하고, 구한 값을 소문항별로 [제출 형식]에 맞춰 입력하시오.
#
# [제공 데이터]
# 1. housing_median_age : 주택 중간 연식
# 2. total_rooms : 총 방 수
# 3. population : 인구 수
# 4. households : 세대 수
# 5. median_income : 중간 소득
# 6. median_house_value : 주택 중간 가격
#
# [수행 순서]
# 1. median_house_value 컬럼에서 IQR 기준으로 이상값을 판단한다.
# ※ 이상값 기준 : 하한선(Q1-1.5 x IQR), 상한선(Q3+1.5 x IQR)
# 2. 위 기준을 벗어나는 이상값들을 제거한다.
# 3. 이상값이 제거된 데이터에 대해 value_per_pop 파생변수를 생성한다.
# ※ value_per_pop = median_house_value / population
# 4. value_per_pop의 평균을 구한다.
#
# [문제]
# 1. 수행 순서 1)에서 계산한 IQR 값을 입력하시오.
# ☞ [제출 형식] 정수(integer)로 작성
# 2. 수행 순서 4)에서 계산한 값을 입력하시오.
# ☞ [제출 형식] 반올림하여 소수 셋째자리까지 작성

# %%
import pandas as pd

df = pd.read_csv('../../sample_data/part1/housing.csv')

df.head()
# 여기에 코드를 작성하시오.
# 1 - 이상값 구하기
Q1 = df['median_house_value'].quantile(.25)
Q3 = df['median_house_value'].quantile(.75)
IQR = Q3 - Q1
print("IQR: ", int(IQR))

outliers = (df['median_house_value'] < Q1 - 1.5*IQR) | (df['median_house_value'] > Q3 + 1.5*IQR)
# 반대 조건 해도 됨.
cond = (df['median_house_value'] >= Q1 - 1.5*IQR) & (df['median_house_value'] <= Q3 + 1.5*IQR)
# 2 - 이상 값 제거
df2 = df[~outliers].copy()

# 3 - 파생 변수 생성
df2['value_per_pop'] = df['median_house_value'] / df['population']

# 4 - 파생 변수 평균 구하기
value_per_pop_mean = df2['value_per_pop'].mean()
print("파생 변수 평균: ", value_per_pop_mean, round(value_per_pop_mean, 3))
# Out:
# IQR:  145125
#    housing_median_age  total_rooms  population  households  median_income  \
# 0                  41          880         322         126         8.3252
# 1                  21         7099        2401        1138         8.3014
# 2                  52         1467         496         177         7.2574
# 3                  52         1274         558         219         5.6431
# 4                  52         1627         565         259         3.8462
#
#    median_house_value
# 0              452600
# 1              358500
# 2              352100
# 3              341300
# 4              342200
#    housing_median_age  total_rooms  population  households  median_income  \
# 0                  41          880         322         126         8.3252
# 1                  21         7099        2401        1138         8.3014
# 2                  52         1467         496         177         7.2574
# ...

# %% [markdown]
# # 풀이

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/BigData/1_DataSet/housing.csv')

# 1. median_house_value 컬럼에서 IQR 기준으로 이상값을 판단한다.
# ※ 이상값 기준 : 하한선(Q1-1.5 x IQR), 상한선(Q3+1.5 x IQR)
q1 = df['median_house_value'].quantile(.25)
q3 = df['median_house_value'].quantile(.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# 2. 위 기준을 벗어나는 이상값들을 제거한다.
df_filtered = df[(df['median_house_value'] >= lower_bound) & (df['median_house_value'] <= upper_bound)].copy()

# 3. 이상값이 제거된 데이터에 대해 value_per_pop 파생변수를 생성한다.
# ※ value_per_pop = median_house_value / population
df_filtered['value_per_pop'] = df_filtered['median_house_value'] / df_filtered['population']

# 4. value_per_pop의 평균을 구한다. (소수 셋째자리까지 반올림)
result = round(df_filtered['value_per_pop'].mean(), 3)

# 결과
print("① iqr 값:", int(iqr))
print("② value_per_pop 평균값:", result)
# Out:
# ① iqr 값: 145125
# ② value_per_pop 평균값: 259.221
